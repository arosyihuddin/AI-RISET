# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/wikipedia.csv")
df.head()
# Out:
#    id   parent_id             timestamp                             hash  \
# 0   1  19472643.0  2022-04-24T00:35:51Z  oo2rvi3f9p4u9czu3opfvbsl0jp9aog
# 1   3  19395623.0  2022-05-05T11:26:32Z  lq3uz0weougma29prpmkm1l5at48s4w
# 2   4  14292725.0  2021-07-05T02:41:20Z  3h1z248a5ic1u3odrse27wg0o0slljl
# 3   5  21368465.0  2022-09-26T04:25:33Z  ololfquhgvu4wzszfu1yaqo3amb8xnm
# 4   6  21768805.0  2022-11-02T02:33:49Z  mkxdb4xfmgse21h6lvtoflnvwlepdb3
#
#                     title                                               text
# 0  Asam deoksiribonukleat  Asam deoksiribonukleat, lebih dikenal dengan s...
# 1             Anwar Sadat  Muhammad Anwar el-Sadat; ) adalah seorang poli...
# 2            Azhar Mansor  Datuk Azhar Mansor adalah orang Malaysia perta...
# 3               Arkeologi  Arkeologi atau ilmu kepurbakalaan adalah ilmu ...
# 4             Antropologi  Antropologi adalah ilmu tentang manusia. Antro...

# %%
kimia = df[df["title"]=="Ilmu komputer"]
kimia
# Out:
#     id   parent_id             timestamp                             hash  \
# 34  45  21417046.0  2022-08-15T21:53:42Z  7fukwhawqqvtrqssg49h0xsrpbuzhps
#
#             title                                               text
# 34  Ilmu komputer  Ilmu komputer (Computer Science), Secara umum ...

# %%
print(kimia["text"][34])
# Out:
# Ilmu komputer (Computer Science), Secara umum diartikan sebagai ilmu yang mempelajari baik tentang komputasi, perangkat keras (hardware) maupun perangkat lunak (software). Ilmu komputer mencakup beragam topik yang berkaitan dengan komputer, mulai dari algoritma hingga subyek yang lebih konkret seperti bahasa pemrograman, perangkat lunak dan perangkat keras. Sebagai suatu disiplin ilmu, Ilmu Komputer lebih menekankan pada pemrograman komputer, dan rekayasa perangkat lunak (software), sementara teknik komputer lebih cenderung berkaitan dengan hal-hal seperti perangkat keras komputer (hardware). Namun, kedua istilah tersebut sering disalah artikan oleh banyak orang.
#
# ...
